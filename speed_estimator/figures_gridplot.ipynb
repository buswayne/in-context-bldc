# %%
# %matplotlib widget
# %matplotlib widget
import os
from pathlib import Path
import time
import torch
import numpy as np
import math
import gc
from functools import partial
from dataset import Dataset, load_dataframes_from_folder, reverse_normalization
from torch.utils.data import DataLoader
from transformer_zerostep import GPTConfig, GPT, warmup_cosine_lr
import argparse
import warnings
import matplotlib.pyplot as plt
import glob
import pandas as pd
import os

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["mathtext.fontset"] = "cm"
plt.rcParams['axes.labelsize']=14
plt.rcParams['xtick.labelsize']=11
plt.rcParams['ytick.labelsize']=11
plt.rcParams['axes.grid']=True
plt.rcParams['axes.xmargin']=0
plt.rcParams['grid.linestyle'] = '--'
plt.rcParams['legend.fontsize']=11

fig_width = 6
fig_width_big = 12

# %%
current_path = os.getcwd().split("in-context-bldc")[0]
data_path = os.path.join(current_path,"in-context-bldc", "data")

folder = "CL_experiments_double_sensor_low_speed_ekf_and_meta/final"
folder_path = os.path.join(data_path, folder)

# %%
list_of_folders = glob.glob(os.path.join(folder_path, '*'))[:6]
print(list_of_folders)
identifiers = [list_of_folders[i].split("_")[-2][-9:] for i in range(len(list_of_folders))]
print(identifiers)

#### inertias [e-4]: I5 = 0.7, I15 = 3.1, I9 = 5.8, I11 = 6.8, I7 = 8.8
order = [0, 5, 2, 3, 1]
list_of_folders = [list_of_folders[j] for j in order]
identifiers = [identifiers[j] for j in order]
print(list_of_folders)
print(identifiers)
# Out:
# ['c:\\Users\\39340\\Documents\\GitHub\\in-context-bldc\\data\\CL_experiments_double_sensor_low_speed_ekf_and_meta/final\\inertia05_ki-0.0029-kp-3.0000', 'c:\\Users\\39340\\Documents\\GitHub\\in-context-bldc\\data\\CL_experiments_double_sensor_low_speed_ekf_and_meta/final\\inertia07_ki-0.0029-kp-3.0000', 'c:\\Users\\39340\\Documents\\GitHub\\in-context-bldc\\data\\CL_experiments_double_sensor_low_speed_ekf_and_meta/final\\inertia09_ki-0.0029-kp-3.0000', 'c:\\Users\\39340\\Documents\\GitHub\\in-context-bldc\\data\\CL_experiments_double_sensor_low_speed_ekf_and_meta/final\\inertia11_ki-0.0029-kp-3.0000', 'c:\\Users\\39340\\Documents\\GitHub\\in-context-bldc\\data\\CL_experiments_double_sensor_low_speed_ekf_and_meta/final\\inertia13_ki-0.0029-kp-3.0000', 'c:\\Users\\39340\\Documents\\GitHub\\in-context-bldc\\data\\CL_experiments_double_sensor_low_speed_ekf_and_meta/final\\inertia15_ki-0.0029-kp-3.0000']
# ['inertia05', 'inertia07', 'inertia09', 'inertia11', 'inertia13', 'inertia15']
# ['c:\\Users\\39340\\Documents\\GitHub\\in-context-bldc\\data\\CL_experiments_double_sensor_low_speed_ekf_and_meta/final\\inertia05_ki-0.0029-kp-3.0000', 'c:\\Users\\39340\\Documents\\GitHub\\in-context-bldc\\data\\CL_experiments_double_sensor_low_speed_ekf_and_meta/final\\inertia15_ki-0.0029-kp-3.0000', 'c:\\Users\\39340\\Documents\\GitHub\\in-context-bldc\\data\\CL_experiments_double_sensor_low_speed_ekf_and_meta/final\\inertia09_ki-0.0029-kp-3.0000', 'c:\\Users\\39340\\Documents\\GitHub\\in-context-bldc\\data\\CL_experiments_double_sensor_low_speed_ekf_and_meta/final\\inertia11_ki-0.0029-kp-3.0000', 'c:\\Users\\39340\\Documents\\GitHub\\in-context-bldc\\data\\CL_experiments_double_sensor_low_speed_ekf_and_meta/final\\inertia07_ki-0.0029-kp-3.0000']
# ['inertia05', 'inertia15', 'inertia09', 'inertia11', 'inertia07']

# %%
profile_list_meta = []
profile_list_ekf = []
profile_list_real = []

for exp_idx in range(len(list_of_folders)):
    profile_config_meta = []
    profile_config_ekf = []
    profile_config_real = []
    exp_path = list_of_folders[exp_idx]
    csv_list = glob.glob(os.path.join(exp_path, "*.csv"))
    for file in csv_list:

        df = pd.read_csv(file)
        profile_config_real.append(df["omega"].to_numpy()[0:2000])
        profile_config_meta.append(df["omega_meta"].to_numpy()[0:2000])
        profile_config_ekf.append(df["omega_ekf"].to_numpy()[0:2000])

    profile_list_real.append(  np.row_stack(profile_config_real)    )
    profile_list_meta.append(  np.row_stack(profile_config_meta)    )
    profile_list_ekf.append(   np.row_stack(profile_config_ekf)     )
    # print(np.row_stack(profile_config_real).shape)

# print(rmse_list_meta)

time = df['t'].to_numpy()[0:2000]
profile_full_real = np.stack(profile_list_real)
profile_full_meta = np.stack(profile_list_meta)
profile_full_ekf = np.stack(profile_list_ekf)
config_number, exp_number, exp_length = profile_full_meta.shape
print(config_number)
print(exp_number)
print(exp_length)
# Out:
# 5
# 15
# 2000

# %%
fig, axes = plt.subplots(4, config_number, figsize=(12, 3), sharex=True)

for config_idx in range(config_number):
# for config_idx in range(1):
    for i in range(3):

        axes[i,config_idx].plot(time,profile_full_meta[config_idx,i,:], label=r"$\hat{\omega}_{\mathcal{F}}$", color="tab:orange", linewidth = 1)
        axes[i,config_idx].plot(time,profile_full_ekf[config_idx,i,:], label=r"$\hat{\omega}_{EKF}$", color="tab:blue", linewidth = 1)
        axes[i,config_idx].plot(time,profile_full_real[config_idx,i,:], label=r"$\omega$", color="k", linestyle=(0, (8, 8)), linewidth = 1)
        axes[i,config_idx].set_ylim([-100, 600])
        if config_idx != 0:
            axes[i,config_idx].set_yticklabels([])
        elif i == 1:
            axes[i,config_idx].set_ylabel(r"$\omega$ [rpm]")


    avg_error_meta = (profile_full_real[config_idx,:,:] - profile_full_meta[config_idx,:,:]).mean(axis = 0)
    avg_error_ekf = (profile_full_real[config_idx,:,:] - profile_full_ekf[config_idx,:,:]).mean(axis = 0)

    std_error_meta = (profile_full_real[config_idx,:,:] - profile_full_meta[config_idx,:,:]).std(axis = 0)
    std_error_ekf = (profile_full_real[config_idx,:,:] - profile_full_ekf[config_idx,:,:]).std(axis = 0)
    


    axes[-1, config_idx].plot(time,avg_error_meta, label=r"$e_{\mathcal{F}}$", color="tab:orange")
    axes[-1, config_idx].fill_between(
        time, 
        avg_error_meta + std_error_meta, 
        avg_error_meta - std_error_meta, 
        color='tab:orange', 
        alpha=0.3
    )

    axes[-1, config_idx].plot(time,avg_error_ekf, label=r"$e_{EKF}$", color="tab:blue")
    axes[-1, config_idx].fill_between(
        time, 
        avg_error_ekf + std_error_ekf, 
        avg_error_ekf - std_error_ekf, 
        color='tab:blue', 
        alpha=0.3
    )
    if config_idx != 0:
        axes[-1,config_idx].set_yticklabels([])
    # else:
    #     axes[-1,config_idx].set_ylabel("Error [RPM]", fontsize=10)

    axes[-1,config_idx].set_ylim([-400, 400])

    
axes[-1,2].set_xlabel("Time [s]")
axes[-1,0].set_ylabel(r"$e_\omega$ [rpm]")
# handles, labels = axes[0, 3].get_legend_handles_labels()
# fig.legend(handles, labels, loc="upper center",bbox_to_anchor=(0.5, 1.0), ncol=3, fontsize=12, frameon=False)
# handles, labels = axes[-1, 3].get_legend_handles_labels()
# fig.legend(handles, labels, loc="lower center", bbox_to_anchor=(0.5, 0.0), ncol=2, fontsize=12, frameon=False)

handles, labels = axes[0, 3].get_legend_handles_labels()

handles[0], handles[1], handles[2] = handles[2], handles[0], handles[1]

labels[0] = "$GT$"
labels[1] = r"$\mathcal{F}$"
labels[2] = "$EKF$"


handles[0].set_dashes([4.5, 4.5])

fig.legend(handles, labels, loc='center left',bbox_to_anchor=(0.92, 0.57), ncol=1, fontsize=12, handlelength=1.2, handletextpad=0.4)
# plt.tight_layout(rect=[0.1, 0.1, 0.9, 0.9])
plt.tight_layout(h_pad=0.05, w_pad=0.3, rect=[0, 0, 0.93, 1])

# plt.subplots_adjust(wspace=0.05, hspace=0.2)
# fig.text(0.0, 0.5, 'speed [rpm]', va='center', rotation='vertical', fontsize=14)


fig.align_ylabels(axes)
plt.savefig("figures\\gridplot_5.pdf", dpi=300)
plt.savefig("figures\\gridplot_5.png")
plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, axes = plt.subplots(4, config_number, figsize=(12, 4), sharex=True)

for config_idx in range(config_number):
# for config_idx in range(1):
    for i in range(3):

        axes[i,config_idx].plot(time,profile_full_meta[config_idx,i,:], label=r"$\hat{\omega}_{\mathcal{F}}$", color="tab:orange", linewidth = 1)
        axes[i,config_idx].plot(time,profile_full_ekf[config_idx,i,:], label=r"$\hat{\omega}_{EKF}$", color="tab:blue", linewidth = 1)
        axes[i,config_idx].plot(time,profile_full_real[config_idx,i,:], label=r"$\omega$", color="k", linestyle=(0, (8, 8)), linewidth = 1)
        axes[i,config_idx].set_ylim([-100, 600])
        if config_idx != 0:
            axes[i,config_idx].set_yticklabels([])
        elif i == 1:
            axes[i,config_idx].set_ylabel("$\omega$ [rpm]")


    avg_error_meta = (profile_full_real[config_idx,:,:] - profile_full_meta[config_idx,:,:]).mean(axis = 0)
    avg_error_ekf = (profile_full_real[config_idx,:,:] - profile_full_ekf[config_idx,:,:]).mean(axis = 0)

    std_error_meta = (profile_full_real[config_idx,:,:] - profile_full_meta[config_idx,:,:]).std(axis = 0)
    std_error_ekf = (profile_full_real[config_idx,:,:] - profile_full_ekf[config_idx,:,:]).std(axis = 0)
    


    axes[-1, config_idx].plot(time,avg_error_meta, label=r"$e_{\mathcal{F}}$", color="tab:orange")
    axes[-1, config_idx].fill_between(
        time, 
        avg_error_meta + std_error_meta, 
        avg_error_meta - std_error_meta, 
        color='tab:orange', 
        alpha=0.3
    )

    axes[-1, config_idx].plot(time,avg_error_ekf, label=r"$e_{EKF}$", color="tab:blue")
    axes[-1, config_idx].fill_between(
        time, 
        avg_error_ekf + std_error_ekf, 
        avg_error_ekf - std_error_ekf, 
        color='tab:blue', 
        alpha=0.3
    )
    if config_idx != 0:
        axes[-1,config_idx].set_yticklabels([])
    # else:
    #     axes[-1,config_idx].set_ylabel("Error [RPM]", fontsize=10)

    axes[-1,config_idx].set_ylim([-400, 400])

    
axes[-1,2].set_xlabel("Time [s]")
handles, labels = axes[0, 3].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center",bbox_to_anchor=(0.5, 1.0), ncol=3, fontsize=12, frameon=False)
handles, labels = axes[-1, 3].get_legend_handles_labels()
fig.legend(handles, labels, loc="lower center", bbox_to_anchor=(0.5, 0.0), ncol=2, fontsize=12, frameon=False)

plt.tight_layout(rect=[0.1, 0.1, 0.9, 0.9])
# plt.tight_layout()
plt.subplots_adjust(wspace=0.05, hspace=0.2)
# fig.text(0.0, 0.5, 'speed [rpm]', va='center', rotation='vertical', fontsize=14)


# plt.savefig("figures\\gridplot_5.pdf", dpi=300)
# plt.savefig("figures\\gridplot_5.png")
plt.show()
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\o'
# <>:14: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\39340\AppData\Local\Temp\ipykernel_34900\2465479589.py:14: SyntaxWarning: invalid escape sequence '\o'
#   axes[i,config_idx].set_ylabel("$\omega$ [rpm]")
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def plot_configs(config_indices, figsize, Legend = True):
    ncols = len(config_indices)
    fig, axes = plt.subplots(4, ncols, figsize=figsize, sharex=True)
    if ncols == 1:
        axes = axes.reshape(-1, 1)  # keep 2D indexing consistent

    for col, config_idx in enumerate(config_indices):
        for i in range(3):
            axes[i, col].plot(time, profile_full_meta[config_idx, i, :],
                               label=r"$\hat{\omega}_{\mathcal{F}}$", color="tab:orange", linewidth=1)
            axes[i, col].plot(time, profile_full_ekf[config_idx, i, :],
                               label=r"$\hat{\omega}_{EKF}$", color="tab:blue", linewidth=1)
            axes[i, col].plot(time, profile_full_real[config_idx, i, :],
                               label=r"$\omega$", color="k", linestyle=(0, (8, 8)), linewidth=1)
            axes[i, col].set_ylim([-100, 600])
            if col != 0:
                axes[i, col].set_yticklabels([])
            elif i == 1:
                axes[i, col].set_ylabel("$\omega$ [rpm]")
            
                

        avg_error_meta = (profile_full_real[config_idx, :, :] - profile_full_meta[config_idx, :, :]).mean(axis=0)
        avg_error_ekf = (profile_full_real[config_idx, :, :] - profile_full_ekf[config_idx, :, :]).mean(axis=0)

        std_error_meta = (profile_full_real[config_idx, :, :] - profile_full_meta[config_idx, :, :]).std(axis=0)
        std_error_ekf = (profile_full_real[config_idx, :, :] - profile_full_ekf[config_idx, :, :]).std(axis=0)

        axes[-1, col].plot(time, avg_error_meta, label=r"$e_{\mathcal{F}}$", color="tab:orange")
        axes[-1, col].fill_between(time, avg_error_meta + std_error_meta, avg_error_meta - std_error_meta,
                                    color='tab:orange', alpha=0.3)

        axes[-1, col].plot(time, avg_error_ekf, label=r"$e_{EKF}$", color="tab:blue")
        axes[-1, col].fill_between(time, avg_error_ekf + std_error_ekf, avg_error_ekf - std_error_ekf,
                                    color='tab:blue', alpha=0.3)
        
        
        if col != 0:
            axes[-1, col].set_yticklabels([])
        else:
            axes[-1, col].set_ylabel("$e$ [rpm]")

        axes[-1, col].set_ylim([-400, 400])

    # x-label on the middle-ish bottom subplot (robust to any ncols)
    # if ncols % 2 == 0:
    #     axes[-1, ncols // 2].set_xlabel("Time [s]")
    # else:
    #     axes[-1, ncols // 2].set_xlabel("Time [s]")
    # fig.supxlabel("Time [s]")

    # legends: pull handles from the last column instead of hardcoded index 3

    if Legend:
        handles, labels = axes[0, -1].get_legend_handles_labels()
        fig.legend(handles, labels, loc="upper center", bbox_to_anchor=(0.5, 1.0), ncol=3, fontsize=12, frameon=False)
        handles, labels = axes[-1, -1].get_legend_handles_labels()
        # fig.legend(handles, labels, loc="lower center", bbox_to_anchor=(0.5, 0.0), ncol=2, fontsize=12, frameon=False)

        legend_lower = fig.legend(handles, labels, loc="lower center",
                            bbox_to_anchor=(0.5, -0.02), ncol=2, fontsize=12, frameon=False)

        plt.tight_layout(rect=[0.1, 0.1, 0.9, 0.9])
        plt.subplots_adjust(wspace=0.05, hspace=0.2)

        # now that layout is finalized, find the legend's top edge in figure coords
        fig.canvas.draw()  # forces layout computation so bboxes are accurate
        legend_bbox = legend_lower.get_window_extent(fig.canvas.get_renderer())
        legend_top_fig = fig.transFigure.inverted().transform(legend_bbox)[1, 1]

        fig.text(0.55, legend_top_fig - 0.015, "Time [s]", ha="center", va="bottom", fontsize=12)
    else:
        fig.text(0.58, 0.09, "Time [s]", ha="center", va="bottom", fontsize=12)



    plt.tight_layout(rect=[0.1, 0.1, 0.9, 0.9])
    plt.subplots_adjust(wspace=0.05, hspace=0.2)

    return fig, axes


# original figsize was (12, 4) for 5 columns -> width per column = 2.4
per_col_width = 12 / config_number  # or hardcode 2.4 if config_number != 5

fig1, axes1 = plot_configs(list(range(3)), figsize=(per_col_width * 3, 3))
# plt.savefig("figures\\gridplot_234.pdf", dpi=300)
# plt.savefig("figures\\gridplot_234.png")
fig2, axes2 = plot_configs(list(range(3, config_number)), figsize=(per_col_width * (config_number - 3), 3), Legend=False)
# plt.savefig("figures\\gridplot_56.pdf", dpi=300)
# plt.savefig("figures\\gridplot_56.png")

plt.show()
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\39340\AppData\Local\Temp\ipykernel_34900\129641285.py:19: SyntaxWarning: invalid escape sequence '\o'
#   axes[i, col].set_ylabel("$\omega$ [rpm]")
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def plot_configs(target_fig, config_indices, ncols_total_width_ratio=None, Legend = False):
    ncols = len(config_indices)
    axes = target_fig.subplots(4, ncols, sharex=True, gridspec_kw={"wspace": 0.05, "hspace": 0.1})
    if ncols == 1:
        axes = axes.reshape(-1, 1)

    for col, config_idx in enumerate(config_indices):
            for i in range(3):
                axes[i, col].plot(time, profile_full_meta[config_idx, i, :],
                                   label=r"$\hat{\omega}_{\mathcal{F}}$", color="tab:orange", linewidth=1)
                axes[i, col].plot(time, profile_full_ekf[config_idx, i, :],
                                   label=r"$\hat{\omega}_{EKF}$", color="tab:blue", linewidth=1)
                axes[i, col].plot(time, profile_full_real[config_idx, i, :],
                                   label=r"$\omega$", color="k", linestyle=(0, (8, 8)), linewidth=1)
                axes[i, col].set_ylim([-100, 600])
                if col != 0:
                    axes[i, col].set_yticklabels([])
                elif i == 1:
                    axes[i, col].set_ylabel("$\omega$ [rpm]")
                
                    
    
            avg_error_meta = (profile_full_real[config_idx, :, :] - profile_full_meta[config_idx, :, :]).mean(axis=0)
            avg_error_ekf = (profile_full_real[config_idx, :, :] - profile_full_ekf[config_idx, :, :]).mean(axis=0)
    
            std_error_meta = (profile_full_real[config_idx, :, :] - profile_full_meta[config_idx, :, :]).std(axis=0)
            std_error_ekf = (profile_full_real[config_idx, :, :] - profile_full_ekf[config_idx, :, :]).std(axis=0)
    
            axes[-1, col].plot(time, avg_error_meta, ":", label=r"$e_{\mathcal{F}}$", color="tab:orange")
            axes[-1, col].fill_between(time, avg_error_meta + std_error_meta, avg_error_meta - std_error_meta,
                                        color='tab:orange', alpha=0.3)
    
            axes[-1, col].plot(time, avg_error_ekf, ":", label=r"$e_{EKF}$", color="tab:blue")
            axes[-1, col].fill_between(time, avg_error_ekf + std_error_ekf, avg_error_ekf - std_error_ekf,
                                        color='tab:blue', alpha=0.3)
            
            
            if col != 0:
                axes[-1, col].set_yticklabels([])
            else:
                axes[-1, col].set_ylabel("$e$ [rpm]")
    
            axes[-1, col].set_ylim([-400, 400])

    # axes[-1, ncols // 2].set_xlabel("Time [s]")  # or the fig.text approach from before

    if Legend:
        # handles, labels = axes[0, -1].get_legend_handles_labels()
        # target_fig.legend(handles, labels, loc="upper center", bbox_to_anchor=(0.5, 1.0),
        #                 ncol=3, fontsize=12, frameon=False)
        # handles, labels = axes[-1, -1].get_legend_handles_labels()
        # legend_lower = target_fig.legend(handles, labels, loc="lower center", bbox_to_anchor=(0.5, 0.0),
        #                                 ncol=2, fontsize=12, frameon=False)
        handles, labels = axes[0, -1].get_legend_handles_labels()
        target_fig.legend(handles, labels, loc="center right", bbox_to_anchor=(1.11, 0.66),
                          ncol=1, fontsize=11, frameon=True)
        handles, labels = axes[-1, -1].get_legend_handles_labels()
        target_fig.legend(handles, labels, loc="center right", bbox_to_anchor=(1.11, 0.267),
                          ncol=1, fontsize=11, frameon=True)

        
    target_fig.subplots_adjust(bottom=0.18, top = 0.95)
    target_fig.text(0.5, 0.01, "Time [s]",
                     ha="center", va="bottom", fontsize=12)

    return axes


ncols_top = 3
ncols_bottom = config_number - 3

fig = plt.figure(figsize=(8, 5))
subfig_top, subfig_bottom_outer = fig.subfigures(2, 1, height_ratios=[1, 1])

# pad = leftover columns' worth of width, split evenly on each side
pad = (ncols_top - ncols_bottom) / 2  # e.g. (3-2)/2 = 0.5
_, subfig_bottom, _ = subfig_bottom_outer.subfigures(
    1, 3, width_ratios=[pad, ncols_bottom, pad]
)

axes1 = plot_configs(subfig_top, list(range(ncols_top)))
axes2 = plot_configs(subfig_bottom, list(range(ncols_top, config_number)), Legend=True)
# fig.subplots_adjust(top=0.95, bottom=0.05, hspace=0.0, vs)
fig.canvas.draw()
# plt.tight_layout()
plt.savefig("figures\\gridplot_thesis.pdf", dpi=300)
plt.savefig("figures\\gridplot_thesis.png")
plt.show()
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# <>:19: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\39340\AppData\Local\Temp\ipykernel_34900\3530926307.py:19: SyntaxWarning: invalid escape sequence '\o'
#   axes[i, col].set_ylabel("$\omega$ [rpm]")
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
