# %%
# %matplotlib widget
# %matplotlib widget
import os
from pathlib import Path
import time
import torch
import numpy as np
import math
import gc
from functools import partial
from dataset_test import Dataset, load_dataframes_from_folder, reverse_normalization
from torch.utils.data import DataLoader
from transformer_zerostep import GPTConfig, GPT, warmup_cosine_lr
import argparse
import warnings
import matplotlib.pyplot as plt
import glob
from itertools import compress

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["mathtext.fontset"] = "cm"
plt.rcParams['axes.labelsize']=14
plt.rcParams['xtick.labelsize']=11
plt.rcParams['ytick.labelsize']=11
plt.rcParams['axes.grid']=True
plt.rcParams['axes.xmargin']=0

# %%
# Overall settings
out_dir = "out"
batch_size = 1024

checkpoint_list = glob.glob(out_dir+r"\*")

# checkpoint_list = checkpoint_list[("50pct" in checkpoint_list) and ("loss_check" not in checkpoint_list)]
mask = [("50pct" in checkpoint_list[i]) and ("loss_check" not in checkpoint_list[i]) for i in range(len(checkpoint_list))]

checkpoint_list=list(compress(checkpoint_list, mask))
print(checkpoint_list)
rmse_list = np.zeros(len(checkpoint_list))
# Out:
# ['out\\ckpt_zerostep_sim_matlab_50pct_h10.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_mix_real_val_noise_h50.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h10.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h10_lr0_1_half_param.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h10_lr0_1_l6h3e12.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h20.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_01.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_05.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_1.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_1_half_param.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_1_l6h3e12.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_5.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_h10.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_h20.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_h50.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_mix_v1.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h10.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h20.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_b256.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_b256_l12h4e8.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_b32.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_b512.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_b512_l8h2e32.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_b512_l8h8e8.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_l8h12e12.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_v1.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_v2.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_v3.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_v4.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_v5.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_v6.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_ss_real_val_v1.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_ss_real_val_v2.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v1.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v2.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v2_20k.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v2_40k.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v2_60k.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v3.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v4.pt']

# %%
for model_idx in range(len(checkpoint_list)):
    model_name = checkpoint_list[model_idx]

    # model_name = "ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_l8h12e12.pt"
    # folder_path = '../data/CL_experiments/test/inertia07_ki-0.0061-kp-11.8427'
    # folder_path = '../data/CL_experiments/test/inertia04_ki-0.0061-kp-11.8427'
    # folder_path = '../../../in-context-bldc/data/simulated/10_percent'
    # folder_path = '../../../in-context-bldc/data/simulated/50_percent_longer_steps'
    folder_path = '../data/CL_experiments/train/inertia13_ki-0.0061-kp-11.8427'

    # Compute settings
    cuda_device = "cuda:0"
    no_cuda = False
    threads = 10
    compile = False

    # Configure compute
    torch.set_num_threads(threads) 
    use_cuda = not no_cuda and torch.cuda.is_available()
    device_name  = cuda_device if use_cuda else "cpu"
    device = torch.device(device_name)
    device_type = 'cuda' if 'cuda' in device_name else 'cpu' # for later use in torch.autocast
    torch.set_float32_matmul_precision("high")
    # Create out dir
    exp_data = torch.load(Path(model_name), map_location=device, weights_only=False)
    seq_len = exp_data["cfg"].seq_len
    nx = exp_data["cfg"].nx
    exp_data["iter_num"]
        
    model_args = exp_data["model_args"]
    gptconf = GPTConfig(**model_args)
    model = GPT(gptconf).to(device)


    state_dict = exp_data["model"]
    unwanted_prefix = '_orig_mod.'
    for k,v in list(state_dict.items()):
        if k.startswith(unwanted_prefix):
            state_dict[k[len(unwanted_prefix):]] = state_dict.pop(k)
        if k.startswith('module.'):
            state_dict[k[7:]] = v
            state_dict.pop(k)

    model.load_state_dict(state_dict)


    size_in_bytes = sum(param.numel() * param.element_size() for param in model.parameters())
    size_in_bytes += sum(buffer.numel() * buffer.element_size() for buffer in model.buffers())


    dfs = load_dataframes_from_folder(folder_path)
    # Log the number of DataFrames loaded

    # Create an instance of the dataset
    dataset_exp = Dataset(dfs=dfs, seq_len=1000)
    dataloader = DataLoader(dataset_exp, batch_size=batch_size, shuffle=True)



    # Example of accessing an item
    batch_u, batch_y = next(iter(dataloader))
    batch_u, batch_y = batch_u.to(device), batch_y.to(device)
    batch_y_pred = torch.empty_like(batch_y)
    cputime = np.empty(batch_y.shape[1])

    b, tt, _ = batch_y.shape 
    H = exp_data["cfg"].seq_len

    ## test each experiment
    df_len = len(dfs)
    rmse = np.zeros(df_len)
    u_full_all = []
    y_full_all = []
    # y_pred_all = []
    for i in range(df_len):
        u_full, y_full = dataset_exp.get_full_experiment(i)
        u_full, y_full = u_full.to(device), y_full.to(device)
        # u_full = torch.stack([u_full], dim=0)
        # y_full = torch.stack([y_full], dim=0)
        # cputime = np.empty(y_full.shape[1])
        # y_pred = torch.empty_like(y_full)

        u_full_all.append(u_full)
        y_full_all.append(y_full)

    u_full_all = torch.stack(u_full_all, dim=0)
    y_full_all = torch.stack(y_full_all, dim=0)
    y_pred_all = torch.empty_like(y_full_all)



    with torch.no_grad():

        for j in range(y_full_all.shape[1]):
            

            if j < H:
                pred = model(u_full_all[:,:j+1, :])
            else:
                pred = model(u_full_all[:,j-H+1:j+1, :])
            
            y_pred_all[:,j,0] = pred[:,-1,0]
        
        u_full_all, y_full_all, y_pred_all  = reverse_normalization(u_full_all, y_full_all, y_pred_all)

    for i in range(df_len):
        y_tmp = y_full_all[i,:,:].cpu().numpy()
        y_pred_tmp = y_pred_all[i,:,:].cpu().numpy()
        rmse[i] = np.sqrt(((y_tmp-y_pred_tmp)**2).mean())

    print("Average rmse: ", rmse.mean())
    rmse_list[model_idx] = rmse.mean()
# Out:
# True
# number of parameters: 0.03M
# Average rmse:  213.13159637451173
# True
# number of parameters: 0.03M
# Average rmse:  134.20639965057373
# True
# number of parameters: 0.03M
# Average rmse:  144.2149616241455
# True
# number of parameters: 0.00M
# Average rmse:  142.5042059326172
# True
# number of parameters: 0.01M
# Average rmse:  166.38867080688476
# True
# number of parameters: 0.03M
# Average rmse:  160.47676200866698
# True
# number of parameters: 0.03M
# Average rmse:  139.72465393066406
# True
# number of parameters: 0.03M
# Average rmse:  143.0601839828491
# True
# number of parameters: 0.03M
# Average rmse:  147.1001463317871
# True
# number of parameters: 0.03M
# Average rmse:  144.01921276092529
# True
# number of parameters: 0.00M
# Average rmse:  147.58477638244628
# True
# number of parameters: 0.01M
# Average rmse:  147.6586399078369
# True
# number of parameters: 0.03M
# Average rmse:  139.40439418792724
# True
# number of parameters: 0.03M
# Average rmse:  186.97785278320313
# True
# number of parameters: 0.03M
# Average rmse:  174.36956581115723
# True
# number of parameters: 0.03M
# Average rmse:  176.9297306060791
# True
# number of parameters: 0.03M
# Average rmse:  207.35853858947755
# True
# number of parameters: 0.03M
# Average rmse:  149.0960317993164
# True
# number of parameters: 0.03M
# Average rmse:  168.11015907287597
# True
# number of parameters: 0.03M
# Average rmse:  147.25799041748047
# True
# number of parameters: 0.03M
# Average rmse:  149.45835021972655
# True
# number of parameters: 0.04M
# Average rmse:  149.6490884399414
# True
# number of parameters: 0.03M
# Average rmse:  170.75948097229005
# True
# number of parameters: 0.03M
# Average rmse:  152.8458924102783
# True
# number of parameters: 0.10M
# Average rmse:  156.51676582336427
# True
# number of parameters: 0.01M
# Average rmse:  151.81811889648438
# True
# number of parameters: 0.01M
# Average rmse:  173.98360412597657
# True
# number of parameters: 0.03M
# Average rmse:  191.4955052947998
# True
# number of parameters: 0.03M
# Average rmse:  223.52184814453125
# True
# number of parameters: 0.03M
# Average rmse:  266.8616299438477
# True
# number of parameters: 0.03M
# Average rmse:  236.4947769165039
# True
# number of parameters: 0.03M
# Average rmse:  196.8807511138916
# True
# number of parameters: 0.03M
# Average rmse:  392.94817306518553
# True
# number of parameters: 0.03M
# Average rmse:  201.2813515472412
# True
# number of parameters: 0.03M
# Average rmse:  223.11948753356933
# True
# number of parameters: 0.03M
# Average rmse:  476.3753671264648
# True
# number of parameters: 0.03M
# Average rmse:  519.7133055114746
# True
# number of parameters: 0.03M
# Average rmse:  244.52809143066406
# True
# number of parameters: 0.03M
# Average rmse:  319.73558197021487
# True
# number of parameters: 0.03M
# Average rmse:  519.7133055114746
# True
# number of parameters: 0.03M
# Average rmse:  493.6915560913086
# True
# number of parameters: 0.03M
# Average rmse:  190.74795440673827

# %%
print(rmse_list)
print(checkpoint_list)

sorted_idxs = np.argsort(rmse_list)
print(sorted_idxs)
sorted_checkpoints = np.array(checkpoint_list)[sorted_idxs]
print(sorted_checkpoints[0:5])
rmse_list.sort()
print(rmse_list[0:5])
# Out:
# [213.13159637 134.20639965 144.21496162 142.50420593 166.38867081
#  160.47676201 139.72465393 143.06018398 147.10014633 144.01921276
#  147.58477638 147.65863991 139.40439419 186.97785278 174.36956581
#  176.92973061 207.35853859 149.0960318  168.11015907 147.25799042
#  149.45835022 149.64908844 170.75948097 152.84589241 156.51676582
#  151.8181189  173.98360413 191.49550529 223.52184814 266.86162994
#  236.49477692 196.88075111 392.94817307 201.28135155 223.11948753
#  476.37536713 519.71330551 244.52809143 319.73558197 519.71330551
#  493.69155609 190.74795441]
# ['out\\ckpt_zerostep_sim_matlab_50pct_h10.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_mix_real_val_noise_h50.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h10.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h10_lr0_1_half_param.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h10_lr0_1_l6h3e12.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h20.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_01.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_05.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_1.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_1_half_param.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_1_l6h3e12.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_5.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_h10.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_h20.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_h50.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_mix_v1.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h10.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h20.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_b256.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_b256_l12h4e8.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_b32.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_b512.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_b512_l8h2e32.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_b512_l8h8e8.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_noise_h50_l8h12e12.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_v1.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_v2.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_v3.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_v4.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_v5.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_real_val_v6.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_ss_real_val_v1.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_ss_real_val_v2.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v1.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v2.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v2_20k.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v2_40k.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v2_60k.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v3.pt', 'out\\ckpt_zerostep_sim_matlab_50pct_v4.pt']
# [ 1 12  6  3  7  9  2  8 19 10 11 17 20 21 25 23 24  5  4 18 22 26 14 15
#  13 41 27 31 33 16  0 34 28 30 37 29 38 32 35 40 36 39]
# ['out\\ckpt_zerostep_sim_matlab_50pct_mix_real_val_noise_h50.pt'
#  'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_5.pt'
#  'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50.pt'
#  'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h10_lr0_1_half_param.pt'
#  'out\\ckpt_zerostep_sim_matlab_50pct_real_val_alt_h50_lr0_01.pt']
# [134.20639965 139.40439419 139.72465393 142.50420593 143.06018398]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
