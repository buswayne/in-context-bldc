# %%
# %matplotlib widget
# %matplotlib widget
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["mathtext.fontset"] = "cm"
plt.rcParams['axes.labelsize']=14
plt.rcParams['xtick.labelsize']=11
plt.rcParams['ytick.labelsize']=11
plt.rcParams['axes.grid']=True
plt.rcParams['axes.xmargin']=0

# %%
# folder_path = '../data/CL_experiments_double_sensor/train/inertia13_ki-0.0061-kp-11.8427/'
# file_path = '../../../in-context-bldc/data/simulated/10_percent/Experiment_2025-01-13_09-03-05.csv'
folder_path = '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta'
exp_number = 10

exp_list = glob.glob(os.path.join(folder_path, '*.csv'))
print(exp_list)

file_path = exp_list[exp_number]
print(file_path)
df = pd.read_csv(file_path)
# Find the first index where r changes from 0 to 1
# first_non_zero_index = df.index[df['r'].diff().gt(0)].min()
# last_index = df.index[df.t > 20].min()
# df = df.loc[first_non_zero_index:last_index]  # Keep rows up to that index
# Out:
# ['../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-24-01_i_omega_3_3369.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-25-08_i_omega_2_3180.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-26-16_i_omega_2_4484.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-27-23_i_omega_3_1280.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-28-30_i_omega_1_7198.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-29-38_i_omega_1_6274.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-30-47_i_omega_3_4439.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-31-56_i_omega_1_8007.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-33-05_i_omega_2_8927.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-34-14_i_omega_2_7912.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-35-23_i_omega_2_8230.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-36-34_i_omega_2_0235.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-37-46_i_omega_2_6906.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-38-54_i_omega_1_5909.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-40-06_i_omega_1_9564.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-41-16_i_omega_3_0804.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-42-27_i_omega_2_3508.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-43-36_i_omega_1_5277.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-44-45_i_omega_2_6214.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-45-55_i_omega_2_4161.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-47-06_i_omega_2_8856.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-48-18_i_omega_2_3533.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-49-28_i_omega_1_8982.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-50-38_i_omega_2_0455.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-51-48_i_omega_3_6603.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-52-57_i_omega_3_1860.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-54-07_i_omega_1_6313.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-55-25_i_omega_3_0771.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-56-36_i_omega_2_3405.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-57-45_i_omega_1_3748.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_20-58-58_i_omega_2_3230.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_21-00-11_i_omega_2_6049.csv', '../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\\Experiment__2025-03-03_21-01-22_i_omega_1_9509.csv', '../.. ...
# ../../../in-context-bldc-data/simulated/50_percent_with_alfa_beta\Experiment__2025-03-03_20-35-23_i_omega_2_8230.csv

# %%
# df

# %%
# Create the figure and subplots with shared x-axis
fig, axes = plt.subplots(3, 1, figsize=(5, 5), sharex=True, constrained_layout=True)

axes[2].plot(df.t, df.vq, label='$v_q$')
axes[2].plot(df.t, df.vd, label='$v_d$')
axes[2].set_ylabel('Voltage [V]')
axes[2].legend(ncols=2)


axes[1].plot(df.t, df.iq, label='$i_q$')
axes[1].plot(df.t, df.id, label='$i_q$')
axes[1].set_ylabel('Current [A]')
axes[1].legend(ncols=2)

axes[0].plot(df.t, df.r, label='$r$')
axes[0].plot(df.t, df.omega, label=r'$\omega$')
axes[0].set_ylabel('Speed [rpm]')
axes[0].legend(ncols=2)

# Set the x-label for the last subplot
axes[-1].set_xlabel('Time (s)')
# Align the y-axis labels to the left
for ax in axes:
    ax.yaxis.set_label_coords(-0.11, 0.5)  # Adjust -0.1 based on figure width
    ax.legend(loc='upper left', ncol=2)

# Tight layout for better spacing
# plt.xlim([9, 12])
# plt.savefig('experiment.pdf')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# for exp_idx in range(len(exp_list)):
#     file_path = exp_list[exp_idx]
#     print(file_path)
#     df = pd.read_csv(file_path)

#     fig, axes = plt.subplots(3, 1, figsize=(5, 5), sharex=True, constrained_layout=True)

#     axes[2].plot(df.t, df.vq, label='$v_q$')
#     axes[2].plot(df.t, df.vd, label='$v_d$')
#     axes[2].set_ylabel('Voltage [V]')
#     axes[2].legend(ncols=2)


#     axes[1].plot(df.t, df.iq, label='$i_q$')
#     axes[1].plot(df.t, df.id, label='$i_q$')
#     axes[1].set_ylabel('Current [A]')
#     axes[1].legend(ncols=2)

#     axes[0].plot(df.t, df.r, label='$r$')
#     axes[0].plot(df.t, df.omega, label=r'$\omega$')
#     axes[0].set_ylabel('Speed [rpm]')
#     axes[0].legend(ncols=2)

#     # Set the x-label for the last subplot
#     axes[-1].set_xlabel('Time (s)')
#     # Align the y-axis labels to the left
#     for ax in axes:
#         ax.yaxis.set_label_coords(-0.11, 0.5)  # Adjust -0.1 based on figure width
#         ax.legend(loc='upper left', ncol=2)
